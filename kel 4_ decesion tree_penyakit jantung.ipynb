# %% [markdown]
# ## IMPORT DATA

# %%
#Kelompok 4
import pandas as pd
import numpy as np

# %% [markdown]
# ## DATASET

# %%
#Kelompok 4
data = pd.read_csv('heart_disease.csv')

# %%
data
# Out:
#      age     sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    male   3       145   233    1        0      150      0      2.3
# 1     37    male   2       130   250    0        1      187      0      3.5
# 2     41  female   1       130   204    0        0      172      0      1.4
# 3     56    male   1       120   236    0        1      178      0      0.8
# 4     57    male   0       140   192    0        1      148      0      0.4
# ..   ...     ...  ..       ...   ...  ...      ...      ...    ...      ...
# 288   63  female   0       124   197    0        1      136      1      0.0
# 289   57  female   0       140   241    0        1      123      1      0.2
# 290   45    male   3       110   264    0        1      132      0      1.2
# 291   68    male   0       144   193    1        1      141      0      3.4
# 292   57  female   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal target
# 0        0   0     1    yes
# 1        0   0     2    yes
# 2        2   0     2    yes
# 3        2   0     2    yes
# 4        1   0     1    yes
# ..     ...  ..   ...    ...
# 288      1   0     2     no
# 289      1   0     3     no
# 290      1   0     3     no
# 291      1   2     3     no
# 292      1   1     2     no
#
# [293 rows x 14 columns]

# %% [markdown]
# ## ENCODING

# %%
data.sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
data.fbs.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
#Kelompok 4
from sklearn.preprocessing import LabelEncoder
for col in ['sex','target']:
    le = LabelEncoder()
    data[col] = le.fit_transform(data[col])

# %%
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    1   0       140   192    0        1      148      0      0.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 288   63    0   0       124   197    0        1      136      1      0.0
# 289   57    0   0       140   241    0        1      123      1      0.2
# 290   45    1   3       110   264    0        1      132      0      1.2
# 291   68    1   0       144   193    1        1      141      0      3.4
# 292   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        1   0     1       1
# ..     ...  ..   ...     ...
# 288      1   0     2       0
# 289      1   0     3       0
# 290      1   0     3       0
# 291      1   2     3       0
# 292      1   1     2       0
#
# [293 rows x 14 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293 entries, 0 to 292
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       293 non-null    int64
#  1   sex       293 non-null    int32
#  2   cp        293 non-null    int64
#  3   trestbps  293 non-null    int64
#  4   chol      293 non-null    int64
#  5   fbs       293 non-null    int64
#  6   restecg   293 non-null    int64
#  7   thalach   293 non-null    int64
#  8   exang     293 non-null    int64
#  9   oldpeak   293 non-null    float64
#  10  slope     293 non-null    int64
#  11  ca        293 non-null    int64
#  12  thal      293 non-null    int64
#  13  target    293 non-null    int32
# dtypes: float64(1), int32(2), int64(11)
# memory usage: 29.9 KB

# %% [markdown]
# ## SPLIT DATA

# %%
#Kelompok 4
# kolom target
y = data['target']

# %%
data.drop('target', axis=1, inplace=True)

# %%
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    1   0       140   192    0        1      148      0      0.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 288   63    0   0       124   197    0        1      136      1      0.0
# 289   57    0   0       140   241    0        1      123      1      0.2
# 290   45    1   3       110   264    0        1      132      0      1.2
# 291   68    1   0       144   193    1        1      141      0      3.4
# 292   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal
# 0        0   0     1
# 1        0   0     2
# 2        2   0     2
# 3        2   0     2
# 4        1   0     1
# ..     ...  ..   ...
# 288      1   0     2
# 289      1   0     3
# 290      1   0     3
# 291      1   2     3
# 292      1   1     2
#
# [293 rows x 13 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data, y, test_size=0.3, random_state=0)

# %% [markdown]
# ## Clasification dengan DecisionTreeClassifier

# %%
#Kelompok 4
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(max_depth=4)

model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=4)

# %% [markdown]
# ## Visualisasi Model

# %%
#Kelompok 4
import matplotlib.pyplot as plt
from sklearn import tree

# %%
feature_names = ['age', 'sex', 'cp', 'trestbps', 'chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal']

# %%
fig = plt.figure(figsize=(100,30))
_ = tree.plot_tree(model,
                  feature_names=feature_names,
                  filled=True)

# %% [markdown]
# ## EVALUASI MODEL

# %%
#Kelompok 4
from sklearn.metrics import classification_report

y_pred = model.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.65      0.75        46
#            1       0.70      0.90      0.79        42
#
#     accuracy                           0.77        88
#    macro avg       0.79      0.78      0.77        88
# weighted avg       0.80      0.77      0.77        88

# %%
from sklearn.metrics import accuracy_score, ConfusionMatrixDisplay, confusion_matrix
print('Decesion Tree model accuracy(in%):',
     accuracy_score(y_test,y_pred)*100)
# Out:
# Decesion Tree model accuracy(in%): 77.27272727272727

# %% [markdown]
# ## Confusion Matrix

# %%
#Kelompok 4
import matplotlib.pyplot as plt
cm=confusion_matrix(y_test, y_pred)
disp=ConfusionMatrixDisplay(confusion_matrix=cm,
                           display_labels=model.classes_)
disp.plot()
plt.show()
